# %% [markdown]
# ### Stable Diffusion - Image generation

# %%
# Import dependent modules 
from tensorflow import keras
import keras_cv
import matplotlib.pyplot as plt

# %%
#Initiating the SD model

img_generator = keras_cv.models.StableDiffusion(
    img_width=512, 
    img_height=512, 
    jit_compile=False
)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
prompt = 'a cat  and a mouse'

images = img_generator.text_to_image(prompt, batch_size=1)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 359ms/step

# %%
plt.imshow(images[0])
plt.axis()
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
prompt = 'a cat chasing a mouse'

images = img_generator.text_to_image(prompt, batch_size=1)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 358ms/step

# %%
plt.imshow(images[0])
plt.axis()
# Out:
# (-0.5, 511.5, 511.5, -0.5)
